# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def read(v):
    n = len(v)
    print("Cargar elementos del vector :")
    for i in range(n):
        v[i] = int(input('casilla['+str(i)+']: '))
n = int(input('valor de n :'))
b = n *[0]
read(b)
# Out:
# valor de n :4
# Cargar elementos del vector :
# casilla[0]: 1
# casilla[1]: 2
# casilla[2]: 3
# casilla[3]: 4

# %%
cadena  = input("ingrese cadena :")
# Out:
# ingrese cadena :f

# %%
print(len(cadena))
# Out:
# 1

# %%
print(len(cadena))
print("--> "+cadena[len(cadena)-1])

La Facultad la odio con toda mi alma.

[0][1][2][3][4][5] -> 6

print("--> " + cadena[0])
# Out:
# 10
# --> a
# --> h

# %%
def Validar(texto):
    for i in cadena:
        print(i)
        if i == '.':
            return True

# %%
Validar(cadena)
# Out:
# H
# o
# l
# a
#
# m
# u
# n
# d
# o
# .
# True

# %%
cadena = "Hola mundo."

# %%
print(cadena)
Validar(cadena)
# Out:
# Hola mundo.
# False

# %%
## cadeana2= [0]=h [1]=o [2]=l [3]=a [4]=' ' ...
cadena2 = "hola mundo"
letras = cadena2[0]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(letras) ## ho -> letras
# Out:
# h

# %%
letras = letras + cadena2[3]
letras = letras + cadena2[4]

# %%
print("->"+letras+"<-")
# Out:
# ->ha <-

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cadena = "Hola mundo."
longitud_palabra = 0
contador = 0
palabra = ''
contador_de_letras = 0
for letra in cadena:
    
    if letra == ' ' or letra == "." :    ## if true   
        print("->"+palabra+"<-")
        print("->",contador_de_letras)
        if contador_de_letras > 4:
            print("correcto")
        contador +=1
        palabra =''
    contador_de_letras += 1
    palabra = palabra + letra  ## hola
    print(palabra)                          ## mundo
# Out:
# H
# Ho
# Hol
# Hola
# ->Hola<-
# -> 4
#
#  m
#  mu
#  mun
#  mund
#  mundo
# -> mundo<-
# -> 10
# .
