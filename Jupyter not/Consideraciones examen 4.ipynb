# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
profesionales = [1,2,3,4]

m =[[None]*columnas for f in range(filas) ]
for profesional in profesionales:
    print(profesional.num_id)
# Out:
# 2
# 3
# 4
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-1a6bcc751919> in <module>
#       1 profesionales = [1,2,3,4]
#       2 for profesional in profesionales:
# ----> 3     print(profesionales[profesional])
#
# IndexError: list index out of range

# %%
naipe = [0,1,2,3,4,5,6,7]  ## 0,8 -> cantidad de valores 9 
columnas = 15
filas = 8
m = [[None]*columnas for f in range(filas)]

print(len(m))


print(len(naipe))
print(naipe[3])
# Out:
# 8
# 8
# 3

# %%
print((1/10) * 100)
# Out:
# 10.0

# %%
print((10/100)*100,'%')
# Out:
# 10.0 %

# %%
a = []
a.append(1)
print(a)
      
a = []
a.append(2)
print(a)
# Out:
# [1]
# [2]
