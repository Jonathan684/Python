# %% [markdown]
#  - Ingreso de valor por teclado del tamaño del vector siempre se valida
#  - Si pidio un numero y carge una cadena no es parte del problema validar eso.
#  -

# %% [markdown]
# Registro

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - prueba(): se invoca solo cuando hacemos run en el registro

# %% [markdown]
# - Orden ascendente

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Orden descendente

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def buscar_mayor_plata(v):
    may = v[0]
    for i in range(1, len(v)):
        if v[i].plata > may.plata:
            may

# %% [markdown]
# - primero se resuelve el or y despues el and

# %% [markdown]
# Porcentaje

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
paises = ['italia' , 'canda']
print(paises[1])
# Out:
# canda

# %%
descripción = ['Caminar' , 'Trepar', 'Escalar', 'Senderismo']
class Actividad():
    def __init__(self, día_partid, descrip, importe, cant_pers, nombr_guia ):
        self.día_partid =  día_partid
        self.descrip = descrip
        self.importe = importe
        self.cant_pers = cant_pers
        self.nombr_guia = nombr_guia
    def __str__(self): 
        s ='Día del partido: {:<10} Descripción: {:<20}Importe para cubrir gastos:{:<10} Cantidad de personas registradas:{:<10} Nombre del guía:{:<10}'
        s = s.format(str(self.día_partid) , descripción[self.descrip], str(self.importe), str(self.cant_pers), self.nombr_guia)
        return s

def prueba():
  a1 = Actividad(23, "natacion", 123, 4, "Nadia")
  print(a1)

if __name__ == "main":
  prueba()


  #Ingrese cantidad de de días de partida: '

#2- Mostrar todos los datos de las actividades, a razón de un registro por línea,
 #que tengan día de partida entre ini y fin, 
 #siendo ini y fin valores enteros que se cargan por teclado.
 #El listado debe salir ordenado por día de partida.
 #Al final del listado, mostrar una línea adicional con la cantidad total de personas que participarán las actividades mostradas en el listado.

#4- Determinar y mostrar el día y la descripción de la actividad que tenga más personas registradas. 
#Si además esa actividad supera una cantidad x (x se carga por teclado) informar con otro mensaje que hará falta un guía extra.
#En el caso de que exista más de una actividad con la misma cantidad de másxima personas mostrar todas,
#y para cada una informar (si corresponde) el mensaje para el guía extra.

# %%
#ENUNCIADO
'''
Un club de treking que acostumbra a organizar actividades al aire libre necesita un programa que permita organizar las actividades del mes. 
De cada actividad se registra:
el día de partida (un número entero entre 1 y 31),
la descripción (una cadena de caracteres), 
el importe que se cobra para cubrir gastos, 
la cantidad de personas registradas 
y el nombre del guía. 
Se desea almacenar la información referida a los n servicios en un arreglo de registros de tipo Actividad (definir el tipo Actividad y cargar n por teclado).

Se pide desarrollar un programa en Python controlado por un menú de opciones y que posea como mínimo dos módulos, que permita gestionar las siguientes tareas:

1- Cargar el arreglo pedido con los datos de las n actividades.
 Valide que el día sea mayor o igual a 1 y menor o igual a 31,
 que el importe a cobrar sea mayor a cero,
 y que la cantidad de personas sea 0 o mayor que 0.
 Puede hacer la carga en forma manual, 
 o puede generar los datos en forma automática (con valores aleatorios) o puede disponer de ambas técnicas si lo desea. 
 Pero al menos una debe programar.

2- Mostrar todos los datos de las actividades, a razón de un registro por línea,
 que tengan día de partida entre ini y fin, 
 siendo ini y fin valores enteros que se cargan por teclado.
 El listado debe salir ordenado por día de partida.
 Al final del listado, mostrar una línea adicional con la cantidad total de personas que participarán las actividades mostradas en el listado.

3- Determinar y mostrar el importe total recaudado por cada posible día del mes.
 En total, 31 acumuladores. Mostrar todos los valores cuyo resultado sea mayor a 0.

4- Determinar y mostrar el día y la descripción de la actividad que tenga más personas registradas. 
Si además esa actividad supera una cantidad x (x se carga por teclado) informar con otro mensaje que hará falta un guía extra.
 En el caso de que exista más de una actividad con la misma cantidad de másxima personas mostrar todas, y para cada una informar (si corresponde) el mensaje para el guía extra.

5- Determinar si existe una actividad para el día d y con descripción t, siendo d y t valores que se carga por teclado. Si exsite, mostrar todos sus datos. 
Si no existe, indicar con un mensaje. Si existe más de una actividad para el día y descripción cargados mostrar solo la primera.

'''




import random 


def validar_entre(min, max,mensaje):
    numero = int(input(mensaje))
    while True:
        if(numero >= min) and (numero <= max):
            return numero       
        else:
            numero = int(input('Error! Ingrese un número comprendido entre 1 y 31: '))

def mostrar_entre(treking):
    acumulador = 4 * [0]
    init = 10#validar_entre(1, 31, 'Ingrese día de partida, inicio: ')
    fin = 20#validar_entre(1, 31, 'Ingrese día de partida, final: ')
    for i in range(len(treking)):
        if (treking[i].día_partid >= init) or (treking[i].día_partid <= fin):
            print("-->",treking[i])
            acumulador[treking[i].descrip] += treking[i].cant_pers
    for k in range(len(acumulador)):
       print("Total de personas" , k , "por esta actividad: " , acumulador[k])         
        
            
        
def pac_practicas (treking):
    acumulador = 30 * [0]  
    for i in range(len(acumulador)):
        for j in range(len(treking)):
            if i == treking[j].tipo_practicas:
                acumulador[i] += 1
    #s = ' '            
    for k in range(len(acumulador)):
        #if(acumulador[k] != -1):
        print( " Tipo de practica ", k ,":  ", 'Cantidad de pacientes por esta especialidad: ' , acumulador[k])
        #s += str(acumulador[k]) +" "
    #print(s)


def num_ID_cant_trat (VECTOR_XXXC, numero_ident, cant_días_tratamiento):
        indice = -1
        for i in range(len(VECTOR_XXXC)):
            if (VECTOR_XXXC[i].numero_identif == numero_ident) and (VECTOR_XXXC[i].cantidad_días <= cant_días_tratamiento):
                indice = i
                break
        if indice != -1:
            print('Existe! \n Los datos del paciente son: ' , VECTOR_XXXC[indice])
        else:
            print('No existe paciente con tal característica!')



def validar_mayor(n,mensaje):
    numero = int(input(mensaje))
    while True:
        if(numero > n):
            return numero       
        else:
            numero = int(input('Error! Ingrese un número mayor a 0: '))
        
def validar_mayor_igual(n):
    numero = int(input('Ingrese cantidad de datos: '))
    while True:
        if(numero >= n):
            return numero       
        else:
            numero = int(input('Error! Ingrese un número mayor o igual a 0: '))
        

def carga_automatica(treking):
    nombr_guia = ['Claudia', 'Jonathan', 'Julia', 'Candelaria', 'Maria', 'Nadia', 'Matias', 'Ana']
   
    for i in range(len(treking)):
        dia_de_partida = random.randint(1, 31)
        descripción = random.randint(0, 3)
        importes = round(random.uniform(0,1000),2)
        cantidad_personas = random.randint(1,100)
        nombre_del_guía = random.choice(nombr_guia)
        treking[i] = Actividad(dia_de_partida, descripción, importes, cantidad_personas, nombre_del_guía )
    return treking 


def ordenar_mayor(treking):
    n = len(treking)
    for i in range(n-1):
        for j in range (i + 1, n):
            if treking[i].nombre_paciente > treking[j].nombre_paciente:
                treking[i] , treking[j] = treking[j], treking[i]
    mostrar(treking)

#def actividad_mayor_personas():


def mostrar (treking):
    for i in range(len (treking)):
        print(treking[i])

def mostrar_menu():
    print('\n')
    print(50 * '*')
    print('CLUB DE TREKING- Menú de opciones')
    print(50 * '*')
    print('1. Ingresar cantidad de datos de las actividades')
    print('2. Mostrar ordenado los datos de las actividades')
    print('3. Importe total reacudado por día')
    print('4. Actividad con más personas registradas y su descripción ')
    print('5. Buscar actividad')
    print('0. Salir')



def principal():
    treking = list() 
    opcion = -1
    while opcion != 0:
        
        mostrar_menu()
        opcion = int(input('\n' 'Elija su opcion :'))
        if opcion == 1:
            n = validar_mayor(0,"Ingrese cantidad de datos: ")
            treking = n * [0]
            treking = carga_automatica (treking)
        else:
            if len (treking) == 0:
                print('\n', ' ERROR! DEBE INGRESAR LA OPCION 1!')  
            elif opcion == 2 :
                mostrar_entre(treking)
            elif opcion == 3:
                (treking)
            elif opcion == 4:
                actividad_mayor_personas()

            elif opcion == 5:
                mostrar(treking)
            elif opcion == 0:
                print('HASTA LUEGO! :) ')


if __name__ == '__main__':
    principal()
