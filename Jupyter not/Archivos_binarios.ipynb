# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Guardan los bytes.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Pickle
# dump volcar al archivo
# load leer

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# getsize() : tamaño. Podemos controlar hasta donde podemos recorrer.

# %% [markdown]
# 0s.path informacion fisica

# %% [markdown]
# ![image.png](attachment:image.png)
