# %%
class empleado:
    pass

e1 = empleado()
e1.nombre = "Juan"
print(e1.nombre)
# Out:
# Juan

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Auto:
    pass

def init(Auto,nomb,lugar):
    Auto.nombre = nomb
    Auto.lugar = lugar
    
    
A1 = Auto() 
init(A1,'Ford','EEUU')
print(A1.nombre)


##rueda = Auto()
##rueda.marca = "Pirrelli"
##print(rueda.marca)
# Out:
# Ford
