# %% [markdown]
# Calculo del tiempo para el Timers

# %% [markdown]
# Formula PERIODO_INT= (RECARGA+1)*PERIODO_CLK

# %% [markdown]
# RECARGA= (PERIODO_INT/PERIODO_CLK)-1

# %%
Tiempo = input("Ingresar el tiempo en seg :")
Recarga = (1*100e6)-1
print(Recarga)
# Out:
# Ingresar el tiempo en seg :1
# 99999999.0

# %%
Inicio = int(input("Tiempo inicial: "))
Final = int(input("Tiempo final: "))
R = (Final - Inicio)/(100e-6)
print(R)
# Out:
# Tiempo inicial: 1
# Tiempo final: 2
# 10000.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Mrx = TiempoMatch/PR[tiempo]-1

# %%
T = 1e-6
PR = (T* 25e6)-1
print(PR)
TiempoMatch = 1
PRS = 10e-6
Mrx = TiempoMatch/(PRS)-1
print(Mrx)
# Out:
# 24.0
# 99998.99999999999
