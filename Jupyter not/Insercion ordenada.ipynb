# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def add_in_order(v, reg):
    izq, der = 0, len(v)-1
    while izq <= der :
        c = (izq + der) // 2
        if v[c].numero == reg.numero:
            pos = c
            break
        if reg.numero < v[c].numero:
            der = c - 1
        else:
            izq = c + 1
            
        if izq > der:
            pos = izq
        v[pos:pos] = [reg]

# %%
class registro:
    def __init__(self, cantidad):
           self.cant = cantidad
    def __str__(self): 
        s ='Número ID: {:^10}'
        s = s.format(str(self.cant))
        return s
            
            
def add_in_order(v, reg):
    izq, der = 0, len(v)-1
    while izq <= der :
        c = (izq + der) // 2
        if v[c].numero == reg.numero:
            pos = c
            break
        if reg.numero < v[c].numero:
            der = c - 1
        else:
            izq = c + 1
            
        if izq > der:
            pos = izq
        v[pos:pos] = [reg]
        
        
    
v = list()
v = [0]*4
v[0] = registro(20)
v[1] = registro(30)


print("->",v[0])
print("->",v[1])
print("->",v[2])
print("->",v[3])
print(v[0].cant)
# Out:
# -> Número ID:     20
# -> Número ID:     30
# -> 0
# -> 0
# 20

# %%
print(4//3)
# Out:
# 1

# %%
a, b = 2, 6
print(a)
# Out:
# 2
