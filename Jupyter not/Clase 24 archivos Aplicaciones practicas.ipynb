# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Insercion de forma ordenada.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Eslasing NO OLVIDAR PONER LOS CORCHETES [REGISTROS]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Reemplazanmos el append con otro metodo.

# %% [markdown]
# La busqueda binaria es la mejor forma de ordenar

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# En izq queda en lugar de la posicion en donde debemos colocar en nuevo valor
# ## UTILIZAR SIEMPRE BUSQUEDA BINARIA TIENE LA MEJOR PERFORMANCE

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import random
tipo_pelicula = random.randint(0, 2)  
print(tipo_pelicula)
# Out:
# 2
