# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Guia de ejercicios Registro py

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Cuando ingreso un valor por teclado debo ver si esta dentro de un intervalo debo validar.

# %% [markdown]
# Busqueda binaria

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# No usar busqueda secuencial si no, usar busqueda binaria

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# CONTROL DE SI EXISTE O NO EL CLIENTE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
